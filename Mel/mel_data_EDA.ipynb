# %%
from google.colab import drive
drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %% [markdown]
# ## import modules

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print('numpy version:', np.__version__)
print('pandas version:', pd.__version__)
# Out:
# numpy version: 1.21.6
# pandas version: 1.3.5

# %% [markdown]
# ## load data

# %%
mel_path = '/content/mydrive/MyDrive/AIFFELTHON/mel_data'

# %%
# data load
mel0 = np.load(mel_path+'/mel_0/arena_mel/0/0.npy')

# 0번째 hz의 db값 변화
db = mel0[0, :]
plt.figure(figsize=(10, 5))
plt.plot(db)
plt.show()

# %%
# 음악파일에서 사용하는 주파수 형태로 변환
t = []
for a in range(0, 1875):
    a1 = mel0[0, a]
    a2 = mel0[0, a+1]
    a3 = a2-a1
    t.append(a3)

plt.figure(figsize=(10,5))
plt.plot(t)
plt.show()

# %% [markdown]
# ## 데이터 변환 후

# %%
mel0_2 = mel0+100

# %%
# 변환 파일의 db값 변화
db2 = mel0_2[0, :]
plt.figure(figsize=(10, 5))
plt.plot(db2)
plt.show()

# %%
# 음악파일에서 사용하는 주파수 형태로 변환
t2 = []
for b in range(0, 1875):
    b1 = mel0_2[0, b]
    b2 = mel0_2[0, b+1]
    b3 = b2-b1
    t2.append(b3)

plt.figure(figsize=(10,5))
plt.plot(t2)
plt.show()
